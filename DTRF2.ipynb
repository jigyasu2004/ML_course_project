# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Kyphosis.csv')

# %%
df.head()
# Out:
#   Kyphosis  Age  Number  Start
# 0   absent   71       3      5
# 1   absent  158       3     14
# 2  present  128       4      5
# 3   absent    2       5      1
# 4   absent    1       4     15

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Kyphosis  81 non-null     object
#  1   Age       81 non-null     int64
#  2   Number    81 non-null     int64
#  3   Start     81 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 2.7+ KB

# %%
sns.pairplot(df,hue='Kyphosis')

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop('Kyphosis',axis=1)

# %%
y=df['Kyphosis']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree = DecisionTreeClassifier()

# %%
dtree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
prediction = dtree.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(confusion_matrix(y_test,prediction))
# Out:
# [[18  4]
#  [ 1  2]]

# %%
print(classification_report(y_test,prediction))
# Out:
#               precision    recall  f1-score   support
#
#       absent       0.95      0.82      0.88        22
#      present       0.33      0.67      0.44         3
#
#     accuracy                           0.80        25
#    macro avg       0.64      0.74      0.66        25
# weighted avg       0.87      0.80      0.83        25

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_estimators = 200)

# %%
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=200)

# %%
rfc_prediction = dtree.predict(X_test)

# %%
print(confusion_matrix(y_test,rfc_prediction))
# Out:
# [[18  4]
#  [ 1  2]]

# %%
print(classification_report(y_test,rfc_prediction))
# Out:
#               precision    recall  f1-score   support
#
#       absent       0.95      0.82      0.88        22
#      present       0.33      0.67      0.44         3
#
#     accuracy                           0.80        25
#    macro avg       0.64      0.74      0.66        25
# weighted avg       0.87      0.80      0.83        25

# %% [markdown]
# #     Tree Visualization

# %%
import sklearn

# %%
plt.figure(figsize=(15,10))
sklearn.tree.plot_tree(dtree,filled = True)
# Out:
# [Text(0.5833333333333334, 0.9375, 'x[2] <= 8.5\ngini = 0.375\nsamples = 56\nvalue = [42, 14]'),
#  Text(0.4166666666666667, 0.8125, 'x[2] <= 4.0\ngini = 0.48\nsamples = 15\nvalue = [6, 9]'),
#  Text(0.3333333333333333, 0.6875, 'x[2] <= 2.5\ngini = 0.444\nsamples = 9\nvalue = [6, 3]'),
#  Text(0.25, 0.5625, 'x[1] <= 6.0\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.16666666666666666, 0.4375, 'x[0] <= 67.0\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.08333333333333333, 0.3125, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.25, 0.3125, 'x[0] <= 77.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.16666666666666666, 0.1875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3333333333333333, 0.1875, 'x[0] <= 105.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.25, 0.0625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4166666666666667, 0.0625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3333333333333333, 0.4375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4166666666666667, 0.5625, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.5, 0.6875, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.75, 0.8125, 'x[2] <= 14.5\ngini = 0.214\nsamples = 41\nvalue = [36, 5]'),
#  Text(0.6666666666666666, 0.6875, 'x[0] <= 47.0\ngini = 0.351\nsamples = 22\nvalue = [17, 5]'),
#  Text(0.5833333333333334, 0.5625, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.75, 0.5625, 'x[0] <= 98.0\ngini = 0.444\nsamples = 15\nvalue = [10, 5]'),
#  Text(0.6666666666666666, 0.4375, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.8333333333333334, 0.4375, 'x[1] <= 3.5\ngini = 0.278\nsamples = 12\nvalue = [10, 2]'),
#  Text(0.75, 0.3125, 'x[0] <= 129.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.6666666666666666, 0.1875, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.8333333333333334, 0.1875, 'x[2] <= 13.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.75, 0.0625, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.9166666666666666, 0.0625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9166666666666666, 0.3125, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.8333333333333334, 0.6875, 'gini = 0.0\nsamples = 19\nvalue = [19, 0]')]

# %%
df
# Out:
#    Kyphosis  Age  Number  Start
# 0    absent   71       3      5
# 1    absent  158       3     14
# 2   present  128       4      5
# 3    absent    2       5      1
# 4    absent    1       4     15
# ..      ...  ...     ...    ...
# 76  present  157       3     13
# 77   absent   26       7     13
# 78   absent  120       2     13
# 79  present   42       7      6
# 80   absent   36       4     13
#
# [81 rows x 4 columns]
